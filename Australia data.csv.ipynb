# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Australia data.csv")

# %%
df[(df["AreaName"]=="Europe") & (df["RegName"]=="Southern Europe")]
# Out:
#                                         OdName CODE AreaName          RegName  \
# 1                                      Albania  ALB   Europe  Southern Europe
# 4                                      Andorra  AND   Europe  Southern Europe
# 25                      Bosnia and Herzegovina  BIH   Europe  Southern Europe
# 51                                     Croatia  HRV   Europe  Southern Europe
# 80                                   Gibraltar  GIB   Europe  Southern Europe
# 81                                      Greece  GRC   Europe  Southern Europe
# 91                                    Holy See  VAT   Europe  Southern Europe
# 101                                      Italy  ITA   Europe  Southern Europe
# 124                                      Malta  MLT   Europe  Southern Europe
# 159                                   Portugal  PRT   Europe  Southern Europe
# 179                                   Slovenia  SVN   Europe  Southern Europe
# ...

# %%
# Out:
# 0       AFG
# 1       ALB
# 2       DZA
# 3       ASM
# 4       AND
#        ...
# 217     WLF
# 218    ESH
# 219     YEM
# 220     ZMB
# 221     ZWE
# Name: CODE, Length: 222, dtype: object
